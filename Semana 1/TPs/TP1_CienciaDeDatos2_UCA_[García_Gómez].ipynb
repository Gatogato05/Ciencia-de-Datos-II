# %% [markdown]
# # Ciencia de Datos II (GES0132) — UCA
# ## Trabajo Práctico N°1: Exploración Inical de Datos de Negocios con Pandas
# **Docente:** Esp. Prof. Diego Vidal Silva (@diegovidalsilva)
# #####**Semana 1:** Trabajo Virtual Asincrónico
#
# ### Objetivos:
# · Configurar y verificar el entorno virtual en la nube (Google Colab)
# #####· Importar la libreria especializada 'pandas'.
# #####· Cargar un dataset real desde un repositorio web (*Open Data*)
# #####· Aplicar inspección estructural: *shape*, *columns*, *head()* y *describe()*
# #####· Formular conclusiones de negocio sobre el fenómeno analizado.

# %% [markdown]
# ### ■ Paso 1: Importación de librerias esenciales

# %%
import pandas as pd
import numpy as np

print('Entorno configurado correctamente')
print(f'Versión de pandas instalada: {pd.__version__}')
# Out:
# Entorno configurado correctamente
# Versión de pandas instalada: 2.2.2

# %% [markdown]
# ### ■ Paso 2: Carga del Dataset desde Fuente Remota (Open Data)
# Cargaré un dataset a mi gusto (es sobre el rendimiento de jugadores de la Copa del Mundo 2026).

# %%
# Carga de dataset remoto desde GitHub
url_dataset = 'https://raw.githubusercontent.com/Gatogato05/Ciencia-de-Datos-II/refs/heads/main/Semana%201/fifa_world_cup_2026_player_performance.csv'

df = pd.read_csv(url_dataset)
print(f"Dataset cargado exitosamente en el DataFrame 'df' desde GitHub:\n{url_dataset}")
# Out:
# Dataset cargado exitosamente en el DataFrame 'df' desde GitHub:
# https://raw.githubusercontent.com/Gatogato05/Ciencia-de-Datos-II/refs/heads/main/Semana%201/fifa_world_cup_2026_player_performance.csv

# %% [markdown]
# ### ■ Paso 3: Inspección Estructural del DataFrame
# Determinamos las dimensiones de la tabla (filas u observaciones x columnas o variables).

# %%
# Inspección de forma (filas, columnas)
filas, columnas = df.shape
print(f'Dimensiones: {filas} filas y {columnas} columnas.\n')

# Lista de variables disponibles
print('Variables en el dataset:')
print(df.columns.tolist())
# Out:
# Dimensiones: 54600 filas y 75 columnas.
#
# Variables en el dataset:
# ...

# %% [markdown]
# ### ■ Paso 4: Muestra de Registros Iniciales
# Visualizamos los primeros 5 registros de la tabla para entender el formato de los datos.

# %%
# Muestra inicial de las primeras 5 observaciones
df.head()
# Out:
#   player_id       player_name  age nationality   team  jersey_number  \
# 0    P00055        Rodri Fati   26     Spanish  Spain              3
# 1    P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2    P00066        Gavi Ramos   18     Spanish  Spain             14
# 3    P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4    P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
#
#      position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# 0  Goalkeeper        195         75           Left  ...              1.10
# 1  Midfielder        178         75          Right  ...              3.50
# 2  Midfielder        177         72           Left  ...             15.30
# 3     Forward        182         74          Right  ...              1.20
# 4    Defender        191         81           Left  ...              6.20
#
#    pressure_resistance creativity_score consistency_score  \
# ...

# %% [markdown]
# ### ■ Paso 5: Diagnóstico de Tipos de Datos y Valores Nulos
# Analizamos si las columnas son numéricas o de texto y verificamos la presencia de datos faltantes.

# %%
# Resumen técnico de tipos de datos y valores no nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54600 entries, 0 to 54599
# Data columns (total 75 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   player_id                 54600 non-null  object
#  1   player_name               54600 non-null  object
#  2   age                       54600 non-null  int64
#  3   nationality               54600 non-null  object
#  4   team                      54600 non-null  object
#  5   jersey_number             54600 non-null  int64
#  6   position                  54600 non-null  object
#  7   height_cm                 54600 non-null  int64
#  8   weight_kg                 54600 non-null  int64
#  9   preferred_foot            54600 non-null  object
#  10  club_name                 54600 non-null  object
#  11  market_value_eur          54600 non-null  int64
#  12  match_id                  54600 non-null  object
# ...

# %% [markdown]
# ### ■ Paso 6: Estadísticos Descriptivos de Negocio
# Calculamos la media, desvío estándar, mínimos, máximos y percentiles cuantitativos.

# %%
# Resumen de métricas de tendencia central y dispersión
pd.options.display.float_format = '{:.2f}'.format
df.describe().T
# Out:
#                             count        mean         std       min  \
# age                      54600.00       26.30        4.07     17.00
# jersey_number            54600.00       13.50        7.50      1.00
# height_cm                54600.00      181.65        6.28    163.00
# weight_kg                54600.00       75.75        3.95     65.00
# market_value_eur         54600.00 20084451.76 27188660.40 528822.00
# ...                           ...         ...         ...       ...
# total_goals_tournament   54600.00        0.64        1.09      0.00
# total_assists_tournament 54600.00        0.61        0.93      0.00
# total_minutes_tournament 54600.00      272.30      116.81      0.00
# player_of_match_awards   54600.00        0.03        0.21      0.00
# tournament_rating        54600.00        3.63        3.16      0.00
#
#                                 25%         50%         75%          max
# age                           23.00       26.00       29.00        39.00
# ...

# %%
# Estadísticas descriptivas para variables cualitativas (texto)
df.describe(include='object').T
# Out:
#                   count unique                       top   freq
# player_id         54600   1248                    P00957     66
# player_name       54600   1245  Pierre-Emile Christensen     86
# nationality       54600     48                    Qatari   1716
# team              54600     48                     Qatar   1716
# position          54600      4                  Defender  18900
# preferred_foot    54600      2                     Right  40656
# club_name         54600    122                 Gor Mahia    892
# match_id          54600   1050                    M01050     52
# match_date        54600     51                2026-06-30   1560
# stadium           54600     16   Lincoln Financial Field   4264
# city              54600     16              Philadelphia   4264
# opponent_team     54600     48                     Qatar   1716
# tournament_stage  54600      7               Group Stage  30056
# match_result      54600      3                         W  20124
